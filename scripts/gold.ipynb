# %%
import os
import json
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode, size, col, countDistinct, array_contains, count, sum
from pyspark.sql.window import Window
os.environ["HADOOP_HOME"] = r"C:\hadoop"
os.environ["PATH"] += os.pathsep + r"C:\hadoop\bin"
os.environ['JAVA_HOME'] = r"D:\Applns\Amazon Corretto\jdk17.0.15_6"
os.environ['PATH'] = r"D:\Applns\Amazon Corretto\jdk17.0.15_6\bin" + os.pathsep + os.environ['PATH']

# %%
spark = SparkSession.builder \
    .master("local[*]") \
    .appName("RumbleVideoETL_gldlayer") \
    .config("spark.ui.port", "4050") \
    .getOrCreate()

# %%
silver_data = spark.read.parquet("../data/silver")
exploaded_video_tag = silver_data.withColumn("video_tag", explode("video_tags"))
exploaded_video_tag.show(n=50, vertical=True)
# Out:
# -RECORD 0---------------------------------
#  video_id          | v5c48et
#  video_url         | https://rumble.co...
#  video_title       | Is Trump Winning ...
#  video_host        | Tim Pool
#  video_duration_s  | 7823
#  video_date        | 2024-08-23 00:00:00
#  video_views       | 3970
#  upvotes_count     | 61
#  downvotes_count   | 4
#  video_description | Host:\nTim Pool
#  video_tags        | [Entertainment, t...
#  comments          | [{0, You're not g...
#  video_tag         | Entertainment
# -RECORD 1---------------------------------
#  video_id          | v5c48et
#  video_url         | https://rumble.co...
#  video_title       | Is Trump Winning ...
#  video_host        | Tim Pool
#  video_duration_s  | 7823
#  video_date        | 2024-08-23 00:00:00
#  video_views       | 3970
#  upvotes_count     | 61
#  downvotes_count   | 4
#  video_description | Host:\nTim Pool
#  video_tags        | [Entertainment, t...
#  comments          | [{0, You're not g...
#  video_tag         | tenet media
# -RECORD 2---------------------------------
#  video_id          | v5c48et
#  video_url         | https://rumble.co...
#  video_title       | Is Trump Winning ...
#  video_host        | Tim Pool
#  video_duration_s  | 7823
#  video_date        | 2024-08-23 00:00:00
#  video_views       | 3970
#  upvotes_count     | 61
#  downvotes_count   | 4
#  video_description | Host:\nTim Pool
#  video_tags        | [Entertainment, t...
#  comments          | [{0, You're not g...
#  video_tag         | the culture war
# -RECORD 3---------------------------------
#  video_id          | v5c48et
#  video_url         | https://rumble.co...
#  video_title       | Is Trump Winning ...
#  video_host        | Tim Pool
#  video_duration_s  | 7823
#  video_date        | 2024-08-23 00:00:00
#  video_views       | 3970
#  upvotes_count     | 61
#  downvotes_count   | 4
#  video_description | Host:\nTim Pool
#  video_tags        | [Entertainment, t...
#  comments          | [{0, You're not g...
#  video_tag         | tim pool podcast
# -RECORD 4---------------------------------
#  video_id          | v5c48et
#  video_url         | https://rumble.co...
#  video_title       | Is Trump Winning ...
#  video_host        | Tim Pool
#  video_duration_s  | 7823
#  video_date        | 2024-08-23 00:00:00
#  video_views       | 3970
#  upvotes_count     | 61
#  downvotes_count   | 4
#  video_description | Host:\nTim Pool
#  video_tags        | [Entertainment, t...
#  comments          | [{0, You're not g...
#  video_tag         | culture war podcast
# -RECORD 5---------------------------------
#  video_id          | v5c48et
#  video_url         | https://rumble.co...
#  video_title       | Is Trump Winning ...
#  video_host        | Tim Pool
#  video_duration_s  | 7823
#  video_date        | 2024-08-23 00:00:00
#  video_views       | 3970
#  upvotes_count     | 61
#  downvotes_count   | 4
#  video_description | Host:\nTim Pool
#  video_tags        | [Entertainment, t...
#  comments          | [{0, You're not g...
#  video_tag         | tim pool
# -RECORD 6---------------------------------
#  video_id          | v5c48et
#  video_url         | https://rumble.co...
#  video_title       | Is Trump Winning ...
#  video_host        | Tim Pool
#  video_duration_s  | 7823
#  video_date        | 2024-08-23 00:00:00
#  video_views       | 3970
#  upvotes_count     | 61
#  downvotes_count   | 4
#  video_description | Host:\nTim Pool
#  video_tags        | [Entertainment, t...
#  comments          | [{0, You're not g...
#  video_tag         | timcast
# -RECORD 7---------------------------------
#  video_id          | v5c48et
#  video_url         | https://rumble.co...
#  video_title       | Is Trump Winning ...
#  video_host        | Tim Pool
#  video_duration_s  | 7823
#  video_date        | 2024-08-23 00:00:00
#  video_views       | 3970
#  upvotes_count     | 61
#  downvotes_count   | 4
#  video_description | Host:\nTim Pool
#  video_tags        | [Entertainment, t...
#  comments          | [{0, You're not g...
#  video_tag         | the culture war p...
# -RECORD 8---------------------------------
#  video_id          | v5c48et
#  video_url         | https://rumble.co...
#  video_title       | Is Trump Winning ...
#  video_host        | Tim Pool
#  video_duration_s  | 7823
#  video_date        | 2024-08-23 00:00:00
#  video_views       | 3970
#  upvotes_count     | 61
#  downvotes_count   | 4
#  video_description | Host:\nTim Pool
#  video_tags        | [Entertainment, t...
#  comments          | [{0, You're not g...
#  video_tag         | trump
# -RECORD 9---------------------------------
#  video_id          | v5c48et
#  video_url         | https://rumble.co...
#  video_title       | Is Trump Winning ...
#  video_host        | Tim Pool
#  video_duration_s  | 7823
#  video_date        | 2024-08-23 00:00:00
#  video_views       | 3970
#  upvotes_count     | 61
#  downvotes_count   | 4
#  video_description | Host:\nTim Pool
#  video_tags        | [Entertainment, t...
#  comments          | [{0, You're not g...
#  video_tag         | kamala harris
# -RECORD 10--------------------------------
#  video_id          | v5d06le
#  video_url         | https://rumble.co...
#  video_title       | Creationism vs Si...
#  video_host        | Tim Pool
#  video_duration_s  | 7581
#  video_date        | 2024-08-30T21:00:...
#  video_views       | 48900
#  upvotes_count     | 126
#  downvotes_count   | 7
#  video_description | Host:\nTim Pool @...
#  video_tags        | [Entertainment]
#  comments          | [{0, When people ...
#  video_tag         | Entertainment
# -RECORD 11--------------------------------
#  video_id          | v5dmwhx
#  video_url         | https://rumble.co...
#  video_title       | Kamala's EMPTY Wo...
#  video_host        | Benny Johnson
#  video_duration_s  | 817
#  video_date        | 2024-09-04T19:00:...
#  video_views       | 8400
#  upvotes_count     | 80
#  downvotes_count   | 3
#  video_description | Benny Johnson and...
#  video_tags        | [News]
#  comments          | [{0, I heard TENE...
#  video_tag         | News
# -RECORD 12--------------------------------
#  video_id          | v5c4c3v
#  video_url         | https://rumble.co...
#  video_title       | Are Americans Sma...
#  video_host        | Tayler Hansen
#  video_duration_s  | 551
#  video_date        | 2024-08-24 00:00:00
#  video_views       | 5920
#  upvotes_count     | 98
#  downvotes_count   | 1
#  video_description | Tayler Hansen ask...
#  video_tags        | [Entertainment, t...
#  comments          | [{0, All governme...
#  video_tag         | Entertainment
# -RECORD 13--------------------------------
#  video_id          | v5c4c3v
#  video_url         | https://rumble.co...
#  video_title       | Are Americans Sma...
#  video_host        | Tayler Hansen
#  video_duration_s  | 551
#  video_date        | 2024-08-24 00:00:00
#  video_views       | 5920
#  upvotes_count     | 98
#  downvotes_count   | 1
#  video_description | Tayler Hansen ask...
#  video_tags        | [Entertainment, t...
#  comments          | [{0, All governme...
#  video_tag         | tenet media
# -RECORD 14--------------------------------
#  video_id          | v5c4c3v
#  video_url         | https://rumble.co...
#  video_title       | Are Americans Sma...
#  video_host        | Tayler Hansen
#  video_duration_s  | 551
#  video_date        | 2024-08-24 00:00:00
#  video_views       | 5920
#  upvotes_count     | 98
#  downvotes_count   | 1
#  video_description | Tayler Hansen ask...
#  video_tags        | [Entertainment, t...
#  comments          | [{0, All governme...
#  video_tag         | tayler hansen
# -RECORD 15--------------------------------
#  video_id          | v5c4c3v
#  video_url         | https://rumble.co...
#  video_title       | Are Americans Sma...
#  video_host        | Tayler Hansen
#  video_duration_s  | 551
#  video_date        | 2024-08-24 00:00:00
#  video_views       | 5920
#  upvotes_count     | 98
#  downvotes_count   | 1
#  video_description | Tayler Hansen ask...
#  video_tags        | [Entertainment, t...
#  comments          | [{0, All governme...
#  video_tag         | mots
# -RECORD 16--------------------------------
#  video_id          | v5c4c3v
#  video_url         | https://rumble.co...
#  video_title       | Are Americans Sma...
#  video_host        | Tayler Hansen
#  video_duration_s  | 551
#  video_date        | 2024-08-24 00:00:00
#  video_views       | 5920
#  upvotes_count     | 98
#  downvotes_count   | 1
#  video_description | Tayler Hansen ask...
#  video_tags        | [Entertainment, t...
#  comments          | [{0, All governme...
#  video_tag         | man on the street
# -RECORD 17--------------------------------
#  video_id          | v5c4c3v
#  video_url         | https://rumble.co...
#  video_title       | Are Americans Sma...
#  video_host        | Tayler Hansen
#  video_duration_s  | 551
#  video_date        | 2024-08-24 00:00:00
#  video_views       | 5920
#  upvotes_count     | 98
#  downvotes_count   | 1
#  video_description | Tayler Hansen ask...
#  video_tags        | [Entertainment, t...
#  comments          | [{0, All governme...
#  video_tag         | street interview
# -RECORD 18--------------------------------
#  video_id          | v5c4c3v
#  video_url         | https://rumble.co...
#  video_title       | Are Americans Sma...
#  video_host        | Tayler Hansen
#  video_duration_s  | 551
#  video_date        | 2024-08-24 00:00:00
#  video_views       | 5920
#  upvotes_count     | 98
#  downvotes_count   | 1
#  video_description | Tayler Hansen ask...
#  video_tags        | [Entertainment, t...
#  comments          | [{0, All governme...
#  video_tag         | las vegas
# -RECORD 19--------------------------------
#  video_id          | v5c4c3v
#  video_url         | https://rumble.co...
#  video_title       | Are Americans Sma...
#  video_host        | Tayler Hansen
#  video_duration_s  | 551
#  video_date        | 2024-08-24 00:00:00
#  video_views       | 5920
#  upvotes_count     | 98
#  downvotes_count   | 1
#  video_description | Tayler Hansen ask...
#  video_tags        | [Entertainment, t...
#  comments          | [{0, All governme...
#  video_tag         | las vegas interview
# -RECORD 20--------------------------------
#  video_id          | v5c4c3v
#  video_url         | https://rumble.co...
#  video_title       | Are Americans Sma...
#  video_host        | Tayler Hansen
#  video_duration_s  | 551
#  video_date        | 2024-08-24 00:00:00
#  video_views       | 5920
#  upvotes_count     | 98
#  downvotes_count   | 1
#  video_description | Tayler Hansen ask...
#  video_tags        | [Entertainment, t...
#  comments          | [{0, All governme...
#  video_tag         | american history
# -RECORD 21--------------------------------
#  video_id          | v5c4c3v
#  video_url         | https://rumble.co...
#  video_title       | Are Americans Sma...
#  video_host        | Tayler Hansen
#  video_duration_s  | 551
#  video_date        | 2024-08-24 00:00:00
#  video_views       | 5920
#  upvotes_count     | 98
#  downvotes_count   | 1
#  video_description | Tayler Hansen ask...
#  video_tags        | [Entertainment, t...
#  comments          | [{0, All governme...
#  video_tag         | american geography
# -RECORD 22--------------------------------
#  video_id          | v5c4c3v
#  video_url         | https://rumble.co...
#  video_title       | Are Americans Sma...
#  video_host        | Tayler Hansen
#  video_duration_s  | 551
#  video_date        | 2024-08-24 00:00:00
#  video_views       | 5920
#  upvotes_count     | 98
#  downvotes_count   | 1
#  video_description | Tayler Hansen ask...
#  video_tags        | [Entertainment, t...
#  comments          | [{0, All governme...
#  video_tag         | american education
# -RECORD 23--------------------------------
#  video_id          | v5ci9np
#  video_url         | https://rumble.co...
#  video_title       | What's Next For R...
#  video_host        | Benny Johnson
#  video_duration_s  | 1340
#  video_date        | 2024-08-27T00:00:...
#  video_views       | 48000
#  upvotes_count     | 192
#  downvotes_count   | 4
#  video_description | Benny Johnson and...
#  video_tags        | [News]
#  comments          | [{0, No! Vaccines...
#  video_tag         | News
# -RECORD 24--------------------------------
#  video_id          | v5c40ii
#  video_url         | https://rumble.co...
#  video_title       | Men Vs Women: Wha...
#  video_host        | Tayler Hansen
#  video_duration_s  | 1146
#  video_date        | 2024-08-23T21:00:...
#  video_views       | 3480
#  upvotes_count     | 40
#  downvotes_count   | 4
#  video_description | Tayler Hansen wen...
#  video_tags        | [Entertainment]
#  comments          | [{0, That’s becau...
#  video_tag         | Entertainment
# -RECORD 25--------------------------------
#  video_id          | v5codsz
#  video_url         | https://rumble.co...
#  video_title       | Politics vs Famil...
#  video_host        | Matt Christiansen
#  video_duration_s  | 953
#  video_date        | 2024-08-28T14:00:...
#  video_views       | 27500
#  upvotes_count     | 156
#  downvotes_count   | 1
#  video_description | Kerry Kennedy is ...
#  video_tags        | [News]
#  comments          | [{0, A sister who...
#  video_tag         | News
# -RECORD 26--------------------------------
#  video_id          | v5crt31
#  video_url         | https://rumble.co...
#  video_title       | Zuck Admits White...
#  video_host        | Matt Christiansen
#  video_duration_s  | 5216
#  video_date        | 2024-08-29T01:00:...
#  video_views       | 6720
#  upvotes_count     | 93
#  downvotes_count   | 1
#  video_description | Mark Zuckerberg t...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, gonna try to...
#  video_tag         | News
# -RECORD 27--------------------------------
#  video_id          | v5crt31
#  video_url         | https://rumble.co...
#  video_title       | Zuck Admits White...
#  video_host        | Matt Christiansen
#  video_duration_s  | 5216
#  video_date        | 2024-08-29T01:00:...
#  video_views       | 6720
#  upvotes_count     | 93
#  downvotes_count   | 1
#  video_description | Mark Zuckerberg t...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, gonna try to...
#  video_tag         | tenet media
# -RECORD 28--------------------------------
#  video_id          | v5crt31
#  video_url         | https://rumble.co...
#  video_title       | Zuck Admits White...
#  video_host        | Matt Christiansen
#  video_duration_s  | 5216
#  video_date        | 2024-08-29T01:00:...
#  video_views       | 6720
#  upvotes_count     | 93
#  downvotes_count   | 1
#  video_description | Mark Zuckerberg t...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, gonna try to...
#  video_tag         | tenet
# -RECORD 29--------------------------------
#  video_id          | v5crt31
#  video_url         | https://rumble.co...
#  video_title       | Zuck Admits White...
#  video_host        | Matt Christiansen
#  video_duration_s  | 5216
#  video_date        | 2024-08-29T01:00:...
#  video_views       | 6720
#  upvotes_count     | 93
#  downvotes_count   | 1
#  video_description | Mark Zuckerberg t...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, gonna try to...
#  video_tag         | Matt Christiansen
# -RECORD 30--------------------------------
#  video_id          | v5crt31
#  video_url         | https://rumble.co...
#  video_title       | Zuck Admits White...
#  video_host        | Matt Christiansen
#  video_duration_s  | 5216
#  video_date        | 2024-08-29T01:00:...
#  video_views       | 6720
#  upvotes_count     | 93
#  downvotes_count   | 1
#  video_description | Mark Zuckerberg t...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, gonna try to...
#  video_tag         | Matt Christiansen...
# -RECORD 31--------------------------------
#  video_id          | v5crt31
#  video_url         | https://rumble.co...
#  video_title       | Zuck Admits White...
#  video_host        | Matt Christiansen
#  video_duration_s  | 5216
#  video_date        | 2024-08-29T01:00:...
#  video_views       | 6720
#  upvotes_count     | 93
#  downvotes_count   | 1
#  video_description | Mark Zuckerberg t...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, gonna try to...
#  video_tag         | Mark Zuckerberg
# -RECORD 32--------------------------------
#  video_id          | v5crt31
#  video_url         | https://rumble.co...
#  video_title       | Zuck Admits White...
#  video_host        | Matt Christiansen
#  video_duration_s  | 5216
#  video_date        | 2024-08-29T01:00:...
#  video_views       | 6720
#  upvotes_count     | 93
#  downvotes_count   | 1
#  video_description | Mark Zuckerberg t...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, gonna try to...
#  video_tag         | Facebook
# -RECORD 33--------------------------------
#  video_id          | v5crt31
#  video_url         | https://rumble.co...
#  video_title       | Zuck Admits White...
#  video_host        | Matt Christiansen
#  video_duration_s  | 5216
#  video_date        | 2024-08-29T01:00:...
#  video_views       | 6720
#  upvotes_count     | 93
#  downvotes_count   | 1
#  video_description | Mark Zuckerberg t...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, gonna try to...
#  video_tag         | Meta
# -RECORD 34--------------------------------
#  video_id          | v5crt31
#  video_url         | https://rumble.co...
#  video_title       | Zuck Admits White...
#  video_host        | Matt Christiansen
#  video_duration_s  | 5216
#  video_date        | 2024-08-29T01:00:...
#  video_views       | 6720
#  upvotes_count     | 93
#  downvotes_count   | 1
#  video_description | Mark Zuckerberg t...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, gonna try to...
#  video_tag         | Instagram
# -RECORD 35--------------------------------
#  video_id          | v5crt31
#  video_url         | https://rumble.co...
#  video_title       | Zuck Admits White...
#  video_host        | Matt Christiansen
#  video_duration_s  | 5216
#  video_date        | 2024-08-29T01:00:...
#  video_views       | 6720
#  upvotes_count     | 93
#  downvotes_count   | 1
#  video_description | Mark Zuckerberg t...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, gonna try to...
#  video_tag         | censorship
# -RECORD 36--------------------------------
#  video_id          | v5crt31
#  video_url         | https://rumble.co...
#  video_title       | Zuck Admits White...
#  video_host        | Matt Christiansen
#  video_duration_s  | 5216
#  video_date        | 2024-08-29T01:00:...
#  video_views       | 6720
#  upvotes_count     | 93
#  downvotes_count   | 1
#  video_description | Mark Zuckerberg t...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, gonna try to...
#  video_tag         | White House
# -RECORD 37--------------------------------
#  video_id          | v5cqqvl
#  video_url         | https://rumble.co...
#  video_title       | Protesters STORM ...
#  video_host        | Tayler Hansen
#  video_duration_s  | 960
#  video_date        | 2024-08-28T19:00:...
#  video_views       | 3560
#  upvotes_count     | 26
#  downvotes_count   | 1
#  video_description | Tayler Hansen wen...
#  video_tags        | [News]
#  comments          | [{0, Okay, so thi...
#  video_tag         | News
# -RECORD 38--------------------------------
#  video_id          | v5dcy2a
#  video_url         | https://rumble.co...
#  video_title       | Kamala's First In...
#  video_host        | Matt Christiansen
#  video_duration_s  | 996
#  video_date        | 2024-09-02T16:30:...
#  video_views       | 7330
#  upvotes_count     | 105
#  downvotes_count   | 2
#  video_description | Matt Christiansen...
#  video_tags        | [News]
#  comments          | [{0, I have a pai...
#  video_tag         | News
# -RECORD 39--------------------------------
#  video_id          | v5c4ee4
#  video_url         | https://rumble.co...
#  video_title       | DNC Riots: Is Any...
#  video_host        | Matt Christiansen
#  video_duration_s  | 598
#  video_date        | 2024-08-25 00:00:00
#  video_views       | 5540
#  upvotes_count     | 127
#  downvotes_count   | 6
#  video_description | Matt Christiansen...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, interesting ...
#  video_tag         | News
# -RECORD 40--------------------------------
#  video_id          | v5c4ee4
#  video_url         | https://rumble.co...
#  video_title       | DNC Riots: Is Any...
#  video_host        | Matt Christiansen
#  video_duration_s  | 598
#  video_date        | 2024-08-25 00:00:00
#  video_views       | 5540
#  upvotes_count     | 127
#  downvotes_count   | 6
#  video_description | Matt Christiansen...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, interesting ...
#  video_tag         | tenet media
# -RECORD 41--------------------------------
#  video_id          | v5c4ee4
#  video_url         | https://rumble.co...
#  video_title       | DNC Riots: Is Any...
#  video_host        | Matt Christiansen
#  video_duration_s  | 598
#  video_date        | 2024-08-25 00:00:00
#  video_views       | 5540
#  upvotes_count     | 127
#  downvotes_count   | 6
#  video_description | Matt Christiansen...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, interesting ...
#  video_tag         | matt christiansen
# -RECORD 42--------------------------------
#  video_id          | v5c4ee4
#  video_url         | https://rumble.co...
#  video_title       | DNC Riots: Is Any...
#  video_host        | Matt Christiansen
#  video_duration_s  | 598
#  video_date        | 2024-08-25 00:00:00
#  video_views       | 5540
#  upvotes_count     | 127
#  downvotes_count   | 6
#  video_description | Matt Christiansen...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, interesting ...
#  video_tag         | johnathan choe
# -RECORD 43--------------------------------
#  video_id          | v5c4ee4
#  video_url         | https://rumble.co...
#  video_title       | DNC Riots: Is Any...
#  video_host        | Matt Christiansen
#  video_duration_s  | 598
#  video_date        | 2024-08-25 00:00:00
#  video_views       | 5540
#  upvotes_count     | 127
#  downvotes_count   | 6
#  video_description | Matt Christiansen...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, interesting ...
#  video_tag         | dnc
# -RECORD 44--------------------------------
#  video_id          | v5c4ee4
#  video_url         | https://rumble.co...
#  video_title       | DNC Riots: Is Any...
#  video_host        | Matt Christiansen
#  video_duration_s  | 598
#  video_date        | 2024-08-25 00:00:00
#  video_views       | 5540
#  upvotes_count     | 127
#  downvotes_count   | 6
#  video_description | Matt Christiansen...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, interesting ...
#  video_tag         | dnc riots
# -RECORD 45--------------------------------
#  video_id          | v5c4ee4
#  video_url         | https://rumble.co...
#  video_title       | DNC Riots: Is Any...
#  video_host        | Matt Christiansen
#  video_duration_s  | 598
#  video_date        | 2024-08-25 00:00:00
#  video_views       | 5540
#  upvotes_count     | 127
#  downvotes_count   | 6
#  video_description | Matt Christiansen...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, interesting ...
#  video_tag         | dnc protests
# -RECORD 46--------------------------------
#  video_id          | v5c4ee4
#  video_url         | https://rumble.co...
#  video_title       | DNC Riots: Is Any...
#  video_host        | Matt Christiansen
#  video_duration_s  | 598
#  video_date        | 2024-08-25 00:00:00
#  video_views       | 5540
#  upvotes_count     | 127
#  downvotes_count   | 6
#  video_description | Matt Christiansen...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, interesting ...
#  video_tag         | dnc chicago
# -RECORD 47--------------------------------
#  video_id          | v5c4ee4
#  video_url         | https://rumble.co...
#  video_title       | DNC Riots: Is Any...
#  video_host        | Matt Christiansen
#  video_duration_s  | 598
#  video_date        | 2024-08-25 00:00:00
#  video_views       | 5540
#  upvotes_count     | 127
#  downvotes_count   | 6
#  video_description | Matt Christiansen...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, interesting ...
#  video_tag         | pro palestine pro...
# -RECORD 48--------------------------------
#  video_id          | v5c4ee4
#  video_url         | https://rumble.co...
#  video_title       | DNC Riots: Is Any...
#  video_host        | Matt Christiansen
#  video_duration_s  | 598
#  video_date        | 2024-08-25 00:00:00
#  video_views       | 5540
#  upvotes_count     | 127
#  downvotes_count   | 6
#  video_description | Matt Christiansen...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, interesting ...
#  video_tag         | palestine protest...
# -RECORD 49--------------------------------
#  video_id          | v5c4ee4
#  video_url         | https://rumble.co...
#  video_title       | DNC Riots: Is Any...
#  video_host        | Matt Christiansen
#  video_duration_s  | 598
#  video_date        | 2024-08-25 00:00:00
#  video_views       | 5540
#  upvotes_count     | 127
#  downvotes_count   | 6
#  video_description | Matt Christiansen...
#  video_tags        | [News, tenet medi...
#  comments          | [{0, interesting ...
#  video_tag         | protests in america
# only showing top 50 rows

# %%
number_of_comments = exploaded_video_tag.withColumn("number_of_comments", size("comments"))
number_of_comments.show(n=30)
# Out:
# +--------+--------------------+--------------------+-----------------+----------------+--------------------+-----------+-------------+---------------+--------------------+--------------------+--------------------+--------------------+------------------+
# |video_id|           video_url|         video_title|       video_host|video_duration_s|          video_date|video_views|upvotes_count|downvotes_count|   video_description|          video_tags|            comments|           video_tag|number_of_comments|
# +--------+--------------------+--------------------+-----------------+----------------+--------------------+-----------+-------------+---------------+--------------------+--------------------+--------------------+--------------------+------------------+
# | v5c48et|https://rumble.co...|Is Trump Winning ...|         Tim Pool|            7823| 2024-08-23 00:00:00|       3970|           61|              4|     Host:\nTim Pool|[Entertainment, t...|[{0, You're not g...|       Entertainment|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|         Tim Pool|            7823| 2024-08-23 00:00:00|       3970|           61|              4|     Host:\nTim Pool|[Entertainment, t...|[{0, You're not g...|         tenet media|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|         Tim Pool|            7823| 2024-08-23 00:00:00|       3970|           61|              4|     Host:\nTim Pool|[Entertainment, t...|[{0, You're not g...|     the culture war|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|         Tim Pool|            7823| 2024-08-23 00:00:00|       3970|           61|              4|     Host:\nTim Pool|[Entertainment, t...|[{0, You're not g...|    tim pool podcast|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|         Tim Pool|            7823| 2024-08-23 00:00:00|       3970|           61|              4|     Host:\nTim Pool|[Entertainment, t...|[{0, You're not g...| culture war podcast|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|         Tim Pool|            7823| 2024-08-23 00:00:00|       3970|           61|              4|     Host:\nTim Pool|[Entertainment, t...|[{0, You're not g...|            tim pool|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|         Tim Pool|            7823| 2024-08-23 00:00:00|       3970|           61|              4|     Host:\nTim Pool|[Entertainment, t...|[{0, You're not g...|             timcast|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|         Tim Pool|            7823| 2024-08-23 00:00:00|       3970|           61|              4|     Host:\nTim Pool|[Entertainment, t...|[{0, You're not g...|the culture war p...|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|         Tim Pool|            7823| 2024-08-23 00:00:00|       3970|           61|              4|     Host:\nTim Pool|[Entertainment, t...|[{0, You're not g...|               trump|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|         Tim Pool|            7823| 2024-08-23 00:00:00|       3970|           61|              4|     Host:\nTim Pool|[Entertainment, t...|[{0, You're not g...|       kamala harris|                14|
# | v5d06le|https://rumble.co...|Creationism vs Si...|         Tim Pool|            7581|2024-08-30T21:00:...|      48900|          126|              7|Host:\nTim Pool @...|     [Entertainment]|[{0, When people ...|       Entertainment|                25|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|    Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|              [News]|[{0, I heard TENE...|                News|                22|
# | v5c4c3v|https://rumble.co...|Are Americans Sma...|    Tayler Hansen|             551| 2024-08-24 00:00:00|       5920|           98|              1|Tayler Hansen ask...|[Entertainment, t...|[{0, All governme...|       Entertainment|                19|
# | v5c4c3v|https://rumble.co...|Are Americans Sma...|    Tayler Hansen|             551| 2024-08-24 00:00:00|       5920|           98|              1|Tayler Hansen ask...|[Entertainment, t...|[{0, All governme...|         tenet media|                19|
# | v5c4c3v|https://rumble.co...|Are Americans Sma...|    Tayler Hansen|             551| 2024-08-24 00:00:00|       5920|           98|              1|Tayler Hansen ask...|[Entertainment, t...|[{0, All governme...|       tayler hansen|                19|
# | v5c4c3v|https://rumble.co...|Are Americans Sma...|    Tayler Hansen|             551| 2024-08-24 00:00:00|       5920|           98|              1|Tayler Hansen ask...|[Entertainment, t...|[{0, All governme...|                mots|                19|
# | v5c4c3v|https://rumble.co...|Are Americans Sma...|    Tayler Hansen|             551| 2024-08-24 00:00:00|       5920|           98|              1|Tayler Hansen ask...|[Entertainment, t...|[{0, All governme...|   man on the street|                19|
# | v5c4c3v|https://rumble.co...|Are Americans Sma...|    Tayler Hansen|             551| 2024-08-24 00:00:00|       5920|           98|              1|Tayler Hansen ask...|[Entertainment, t...|[{0, All governme...|    street interview|                19|
# | v5c4c3v|https://rumble.co...|Are Americans Sma...|    Tayler Hansen|             551| 2024-08-24 00:00:00|       5920|           98|              1|Tayler Hansen ask...|[Entertainment, t...|[{0, All governme...|           las vegas|                19|
# | v5c4c3v|https://rumble.co...|Are Americans Sma...|    Tayler Hansen|             551| 2024-08-24 00:00:00|       5920|           98|              1|Tayler Hansen ask...|[Entertainment, t...|[{0, All governme...| las vegas interview|                19|
# | v5c4c3v|https://rumble.co...|Are Americans Sma...|    Tayler Hansen|             551| 2024-08-24 00:00:00|       5920|           98|              1|Tayler Hansen ask...|[Entertainment, t...|[{0, All governme...|    american history|                19|
# | v5c4c3v|https://rumble.co...|Are Americans Sma...|    Tayler Hansen|             551| 2024-08-24 00:00:00|       5920|           98|              1|Tayler Hansen ask...|[Entertainment, t...|[{0, All governme...|  american geography|                19|
# | v5c4c3v|https://rumble.co...|Are Americans Sma...|    Tayler Hansen|             551| 2024-08-24 00:00:00|       5920|           98|              1|Tayler Hansen ask...|[Entertainment, t...|[{0, All governme...|  american education|                19|
# | v5ci9np|https://rumble.co...|What's Next For R...|    Benny Johnson|            1340|2024-08-27T00:00:...|      48000|          192|              4|Benny Johnson and...|              [News]|[{0, No! Vaccines...|                News|                10|
# | v5c40ii|https://rumble.co...|Men Vs Women: Wha...|    Tayler Hansen|            1146|2024-08-23T21:00:...|       3480|           40|              4|Tayler Hansen wen...|     [Entertainment]|[{0, That’s becau...|       Entertainment|                 4|
# | v5codsz|https://rumble.co...|Politics vs Famil...|Matt Christiansen|             953|2024-08-28T14:00:...|      27500|          156|              1|Kerry Kennedy is ...|              [News]|[{0, A sister who...|                News|                23|
# | v5crt31|https://rumble.co...|Zuck Admits White...|Matt Christiansen|            5216|2024-08-29T01:00:...|       6720|           93|              1|Mark Zuckerberg t...|[News, tenet medi...|[{0, gonna try to...|                News|                 5|
# | v5crt31|https://rumble.co...|Zuck Admits White...|Matt Christiansen|            5216|2024-08-29T01:00:...|       6720|           93|              1|Mark Zuckerberg t...|[News, tenet medi...|[{0, gonna try to...|         tenet media|                 5|
# | v5crt31|https://rumble.co...|Zuck Admits White...|Matt Christiansen|            5216|2024-08-29T01:00:...|       6720|           93|              1|Mark Zuckerberg t...|[News, tenet medi...|[{0, gonna try to...|               tenet|                 5|
# | v5crt31|https://rumble.co...|Zuck Admits White...|Matt Christiansen|            5216|2024-08-29T01:00:...|       6720|           93|              1|Mark Zuckerberg t...|[News, tenet medi...|[{0, gonna try to...|   Matt Christiansen|                 5|
# +--------+--------------------+--------------------+-----------------+----------------+--------------------+-----------+-------------+---------------+--------------------+--------------------+--------------------+--------------------+------------------+
# only showing top 30 rows

# %%
exploade_comments = number_of_comments.withColumn("comments",explode("comments"))
exploade_comments.show()
# Out:
# +--------+--------------------+--------------------+----------+----------------+-------------------+-----------+-------------+---------------+-----------------+--------------------+--------------------+-------------+------------------+
# |video_id|           video_url|         video_title|video_host|video_duration_s|         video_date|video_views|upvotes_count|downvotes_count|video_description|          video_tags|            comments|    video_tag|number_of_comments|
# +--------+--------------------+--------------------+----------+----------------+-------------------+-----------+-------------+---------------+-----------------+--------------------+--------------------+-------------+------------------+
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{0, You're not go...|Entertainment|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{1, I wonder how ...|Entertainment|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{2, When Jamal Gr...|Entertainment|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{3, this has got ...|Entertainment|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{4, I would bet t...|Entertainment|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{5, pointing out ...|Entertainment|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{6, it is not tru...|Entertainment|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{7, not for nothi...|Entertainment|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{8, Tim, why are ...|Entertainment|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{9, That guy is c...|Entertainment|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{10, In my neighb...|Entertainment|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{11, 24-08-31, so...|Entertainment|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{12, Ok, part 2, ...|Entertainment|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{13, Who gives a ...|Entertainment|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{0, You're not go...|  tenet media|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{1, I wonder how ...|  tenet media|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{2, When Jamal Gr...|  tenet media|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{3, this has got ...|  tenet media|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{4, I would bet t...|  tenet media|                14|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{5, pointing out ...|  tenet media|                14|
# +--------+--------------------+--------------------+----------+----------------+-------------------+-----------+-------------+---------------+-----------------+--------------------+--------------------+-------------+------------------+
# only showing top 20 rows

# %%
commented_users = exploade_comments.select(
    "video_id",
    "comments.username_hash"
).dropna()
users_count = commented_users.groupBy("video_id").agg(countDistinct("username_hash").alias("number_of_commented_users"))
users_count.show()
# Out:
# +--------+-------------------------+
# |video_id|number_of_commented_users|
# +--------+-------------------------+
# | v5cqqvl|                        1|
# | v5c4ee4|                       11|
# | v5d0f90|                        4|
# | v5c40ii|                        4|
# | v5codsz|                       22|
# | v5d2f3t|                        2|
# | v5dmwhx|                       18|
# | v5cmmn9|                        7|
# | v5cwrdf|                       10|
# | v5c5ydx|                       12|
# | v5c48et|                        8|
# | v5ci9np|                       10|
# | v5c4c3v|                       18|
# | v5dcy2a|                        6|
# | v5d06le|                       16|
# | v5d2heh|                       18|
# | v5crt31|                        5|
# | v5cvnlf|                        6|
# | v5bwjq5|                        3|
# +--------+-------------------------+

# %% [markdown]
# #Golden Layer1

# %%
gold_layer1 = exploade_comments.join(users_count, on="video_id", how="left")
gold_layer1.show()
gold_layer1.write.mode("overwrite").parquet("../data/gold/gold_layer1")
# Out:
# +--------+--------------------+--------------------+----------+----------------+-------------------+-----------+-------------+---------------+-----------------+--------------------+--------------------+-------------+------------------+-------------------------+
# |video_id|           video_url|         video_title|video_host|video_duration_s|         video_date|video_views|upvotes_count|downvotes_count|video_description|          video_tags|            comments|    video_tag|number_of_comments|number_of_commented_users|
# +--------+--------------------+--------------------+----------+----------------+-------------------+-----------+-------------+---------------+-----------------+--------------------+--------------------+-------------+------------------+-------------------------+
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{0, You're not go...|Entertainment|                14|                        8|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{1, I wonder how ...|Entertainment|                14|                        8|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{2, When Jamal Gr...|Entertainment|                14|                        8|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{3, this has got ...|Entertainment|                14|                        8|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{4, I would bet t...|Entertainment|                14|                        8|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{5, pointing out ...|Entertainment|                14|                        8|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{6, it is not tru...|Entertainment|                14|                        8|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{7, not for nothi...|Entertainment|                14|                        8|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{8, Tim, why are ...|Entertainment|                14|                        8|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{9, That guy is c...|Entertainment|                14|                        8|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{10, In my neighb...|Entertainment|                14|                        8|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{11, 24-08-31, so...|Entertainment|                14|                        8|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{12, Ok, part 2, ...|Entertainment|                14|                        8|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{13, Who gives a ...|Entertainment|                14|                        8|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{0, You're not go...|  tenet media|                14|                        8|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{1, I wonder how ...|  tenet media|                14|                        8|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{2, When Jamal Gr...|  tenet media|                14|                        8|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{3, this has got ...|  tenet media|                14|                        8|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{4, I would bet t...|  tenet media|                14|                        8|
# | v5c48et|https://rumble.co...|Is Trump Winning ...|  Tim Pool|            7823|2024-08-23 00:00:00|       3970|           61|              4|  Host:\nTim Pool|[Entertainment, t...|{5, pointing out ...|  tenet media|                14|                        8|
# +--------+--------------------+--------------------+----------+----------------+-------------------+-----------+-------------+---------------+-----------------+--------------------+--------------------+-------------+------------------+-------------------------+
# only showing top 20 rows

# %% [markdown]
# #Golden Layer 2

# %%
gold_layer1 = spark.read.parquet("../data/gold/gold_layer1")
# gold_layer1.show()

gold_layer2 = gold_layer1.filter((gold_layer1["video_host"] == "Benny Johnson") & (array_contains(gold_layer1["video_tags"], "News")))

gold_layer2.show()
gold_layer2.write.mode("overwrite").parquet("../data/gold/gold_layer2")
# Out:
# +--------+--------------------+--------------------+-------------+----------------+--------------------+-----------+-------------+---------------+--------------------+----------+--------------------+---------+------------------+-------------------------+
# |video_id|           video_url|         video_title|   video_host|video_duration_s|          video_date|video_views|upvotes_count|downvotes_count|   video_description|video_tags|            comments|video_tag|number_of_comments|number_of_commented_users|
# +--------+--------------------+--------------------+-------------+----------------+--------------------+-----------+-------------+---------------+--------------------+----------+--------------------+---------+------------------+-------------------------+
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{0, I heard TENET...|     News|                22|                       18|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{1, Pray for RT n...|     News|                22|                       18|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{2, She's a Fake ...|     News|                22|                       18|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{3, We love you T...|     News|                22|                       18|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{4, Free Lauren C...|     News|                22|                       18|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{5, So no issues ...|     News|                22|                       18|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{6, Rachel MadCow...|     News|                22|                       18|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{7, CBC is report...|     News|                22|                       18|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{8, for all of y'...|     News|                22|                       18|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{9, Hope you're a...|     News|                22|                       18|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{10, Best I could...|     News|                22|                       18|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{11, Supreme Cour...|     News|                22|                       18|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{12, Your right, ...|     News|                22|                       18|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{13, So glad I he...|     News|                22|                       18|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{14, so tenets do...|     News|                22|                       18|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{15, Do you remem...|     News|                22|                       18|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{16, I think she ...|     News|                22|                       18|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{17, idiot, true,...|     News|                22|                       18|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{18, You are too ...|     News|                22|                       18|
# | v5dmwhx|https://rumble.co...|Kamala's EMPTY Wo...|Benny Johnson|             817|2024-09-04T19:00:...|       8400|           80|              3|Benny Johnson and...|    [News]|{19, More of you ...|     News|                22|                       18|
# +--------+--------------------+--------------------+-------------+----------------+--------------------+-----------+-------------+---------------+--------------------+----------+--------------------+---------+------------------+-------------------------+
# only showing top 20 rows

# %% [markdown]
# #Gold Layer 3

# %%
gold_layer2  = spark.read.parquet("../data/gold/gold_layer2")
# gold_layer2.show()
explode = gold_layer2.select("video_id","comments")
# explode.show()
user_comments = explode.select("video_id",
    col("comments.username_hash").alias("username_hash"),
    col("comments.num_likes").alias("likes")
)
user_comments.show()
# Out:
# +--------+-----------------+-----+
# |video_id|    username_hash|likes|
# +--------+-----------------+-----+
# | v5cwrdf|  768a13ee19f869f|    4|
# | v5cwrdf|  768a13ee19f869f|    4|
# | v5cwrdf|x7302e0aea80c6e7f|    2|
# | v5cwrdf|x7302e0aea80c6e7f|    2|
# | v5cwrdf| 3b49236d844754a9|    1|
# | v5cwrdf|x75767465b0479afa|    0|
# | v5cwrdf|x54c9c226e00a85b0|    0|
# | v5cwrdf|x548a925eb2b191d0|    0|
# | v5cwrdf| 7a92ab03edd1cb9d|    0|
# | v5cwrdf|x621a53ff9a2f37ca|    0|
# | v5cwrdf| 64aa69972841fd06|    0|
# | v5cwrdf| 26a520314654c7ab|    0|
# | v5cwrdf| 26a520314654c7ab|    0|
# | v5cwrdf| 26a520314654c7ab|    0|
# | v5dmwhx|x555878aa98066637|   13|
# | v5dmwhx| 47522f6251808e98|    4|
# | v5dmwhx|x555878aa98066637|    3|
# | v5dmwhx| 1af378e7a8f87c24|    3|
# | v5dmwhx| 52d69853c2dfef64|    3|
# | v5dmwhx|x26028a9fd839421f|    2|
# +--------+-----------------+-----+
# only showing top 20 rows

# %%
agg = user_comments.groupBy("video_id", "username_hash").agg(
    count("*").alias("number_of_comments"),
    sum("likes").alias("number_of_comments_like")
)
agg.show()
agg.write.mode("overwrite").parquet("../data/gold/gold_layer3")
# Out:
# +--------+-----------------+------------------+-----------------------+
# |video_id|    username_hash|number_of_comments|number_of_comments_like|
# +--------+-----------------+------------------+-----------------------+
# | v5cwrdf| 64aa69972841fd06|                 1|                      0|
# | v5cwrdf| 26a520314654c7ab|                 3|                      0|
# | v5cwrdf| 3b49236d844754a9|                 1|                      1|
# | v5cwrdf|x75767465b0479afa|                 1|                      0|
# | v5cwrdf| 7a92ab03edd1cb9d|                 1|                      0|
# | v5cwrdf|x548a925eb2b191d0|                 1|                      0|
# | v5cwrdf|  768a13ee19f869f|                 2|                      8|
# | v5cwrdf|x7302e0aea80c6e7f|                 2|                      4|
# | v5cwrdf|x54c9c226e00a85b0|                 1|                      0|
# | v5cwrdf|x621a53ff9a2f37ca|                 1|                      0|
# | v5dmwhx| 4974a64c1652952b|                 1|                      1|
# | v5dmwhx| 1af378e7a8f87c24|                 1|                      3|
# | v5dmwhx|x2f32fba7feb857d6|                 1|                      0|
# | v5dmwhx| 52d69853c2dfef64|                 1|                      3|
# | v5dmwhx|x1ce7f4da0d031505|                 2|                      0|
# | v5dmwhx| 47522f6251808e98|                 2|                      4|
# | v5dmwhx| 7ddf5ac8fe3d8f21|                 1|                      0|
# | v5dmwhx| 1f1fe9230504e64d|                 1|                      1|
# | v5dmwhx| 5a11e961e07391ae|                 1|                      1|
# | v5dmwhx| 6d6f181c78409685|                 1|                      1|
# +--------+-----------------+------------------+-----------------------+
# only showing top 20 rows

# %%
spark.stop()
